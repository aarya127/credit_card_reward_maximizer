# %%
pip install pdfplumber pyspark openai requests bs4 selenium webdriver-manager faiss-cpu transformers sentence-transformers
# Out:
# Requirement already satisfied: pdfplumber in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (0.11.4)
# Requirement already satisfied: pyspark in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (3.4.1)
# Requirement already satisfied: openai in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (1.52.1)
# Requirement already satisfied: requests in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (2.32.3)
# Requirement already satisfied: bs4 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (0.0.2)
# Requirement already satisfied: selenium in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (4.24.0)
# Requirement already satisfied: webdriver-manager in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (4.0.2)
# Requirement already satisfied: faiss-cpu in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (1.9.0.post1)
# Requirement already satisfied: transformers in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (4.46.2)
# Requirement already satisfied: sentence-transformers in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (3.3.1)
# Requirement already satisfied: pdfminer.six==20231228 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pdfminer.six==20231228->pdfplumber) (43.0.3)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/aaryas127/.local/lib/python3.11/site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/aaryas127/.local/lib/python3.11/site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /Users/aaryas127/.local/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: beautifulsoup4 in /Users/aaryas127/.local/lib/python3.11/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: trio~=0.17 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: websocket-client~=1.8 in /Users/aaryas127/.local/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: python-dotenv in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from webdriver-manager) (1.0.1)
# Requirement already satisfied: packaging in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from webdriver-manager) (24.1)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from faiss-cpu) (2.1.3)
# Requirement already satisfied: filelock in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (0.24.6)
# Requirement already satisfied: pyyaml>=5.1 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from transformers) (0.20.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from sentence-transformers) (2.3.0.post101)
# Requirement already satisfied: scikit-learn in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: httpcore==1.* in /Users/aaryas127/.local/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/aaryas127/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: sympy in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.13.2)
# Requirement already satisfied: networkx in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: attrs>=23.2.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/aaryas127/.local/lib/python3.11/site-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: joblib>=1.2.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: cffi>=1.12 in /Users/aaryas127/.local/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/aaryas127/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: pycparser in /Users/aaryas127/.local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdfplumber
import pandas as pd

def extract_pdf_data(file_path):
    """
    Extracts data from the credit card PDF and structures it for a pandas DataFrame.
    """
    data = []
    with pdfplumber.open(file_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            lines = text.split("\n")
            
            # Parse lines for credit card information
            for i in range(len(lines)):
                if "%" in lines[i]:  # Heuristic: look for interest rate
                    # Extract card details (sample parsing logic, adjust as needed)
                    try:
                        card_name = lines[i - 3].strip()
                        bank = lines[i - 2].strip()
                        annual_fee = lines[i + 1].split(" ")[0].strip() if "fee" in lines[i + 1].lower() else "No annual fee"
                        interest_rate = float(lines[i].split("%")[0].strip())
                        rewards = None
                        
                        # Check for rewards (look at subsequent lines)
                        rewards_lines = []
                        j = i + 2
                        while j < len(lines) and ":" in lines[j]:
                            rewards_lines.append(lines[j].split(":")[1].strip())
                            j += 1
                        
                        if rewards_lines:
                            rewards = ", ".join(rewards_lines)
                        
                        # Append to data
                        data.append((card_name, bank, annual_fee, interest_rate, rewards))
                    except Exception as e:
                        print(f"Skipping line due to parsing error: {e}")
                        continue
    return data

# Path to the PDF file
pdf_path = "/Users/aaryas127/Documents/GitHub/credit_card_reward_maximizer/data_storage/SearchCreditCard-eng.pdf"

# Extract data from the PDF
parsed_data = extract_pdf_data(pdf_path)

# Create a pandas DataFrame from the parsed data
df = pd.DataFrame(parsed_data, columns=["Card Name", "Bank", "Annual Fee", "Purchase Interest Rate (%)", "Rewards"])

# Show the DataFrame
print(df)
# Out:
#                                              Card Name  \
# 0                                Desjardins Flexi Visa
# 1                          MBNA True Line® Mastercard®
# 2           Coast Capital Collabria Classic Mastercard
# 3                     Tangerine Money-Back Credit Card
# 4                           Tangerine World Mastercard
# ..                                                 ...
# 99          CIBC Aeroplan Visa Infinite Privilege Card
# 100           TD Aeroplan Visa Infinite Privilege Card
# 101  American Express® Aeroplan®* Reserve Card (Cre...
# 102  American Express® Aeroplan®* Reserve Card (Cha...
# 103                                  The Platinum Card
#
#                                                 Bank     Annual Fee  \
# 0                                         Desjardins  No annual fee
# 1    MBNA is a division of The Toronto-Dominion Bank  No annual fee
# 2                              Coast Capital Savings  No annual fee
# 3                                     Tangerine Bank  No annual fee
# 4                                     Tangerine Bank  No annual fee
# ..                                               ...            ...
# 99                                              CIBC  No annual fee
# 100                        The Toronto-Dominion Bank  No annual fee
# 101                              Amex Bank of Canada  No annual fee
# 102                              Amex Bank of Canada  No annual fee
# 103                              Amex Bank of Canada  No annual fee
#
#      Purchase Interest Rate (%) Rewards
# 0                         10.90    None
# 1                         12.99    None
# 2                         13.99    None
# 3                         19.95
# 4                         19.95
# ..                          ...     ...
# 99                        20.99
# 100                       20.99
# 101                       21.99
# 102                       30.00
# 103                       30.00
#
# [104 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage to scrape
url = r"https://rates.ca/credit-cards/travel"

# Send a GET request to fetch the page content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.content, 'html.parser')

    # Print the entire page content
    print("Page Title:", soup.title.string)  # Print the title of the page

    # Extract all text
    print("Full Page Text:")
    print(soup.get_text())

    # If you want to extract all links
    print("\nAll Links on the Page:")
    for link in soup.find_all('a', href=True):
        print(link['href'])

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Page Title: Canada's Best Travel Credit Cards of 2024
# Full Page Text:
#
#
#
#
#
# Canada's Best Travel Credit Cards of 2024
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Car Insurance
#
# Car Insurance +−
#
#
#
#
#
# Car Insurance
#
#
# Ontario Car Insurance
#
#
# Alberta Car Insurance
#
#
# Quebec Car Insurance
#
#
# Bundle Home & Car
#                                         Insurance
#
#
#
#
#
#
#
#
#
#
#
# Ratesbot
#
#
#                                             Automated carinsurance shopping
#
#
#
#
#
#
#
#
#
# Home Insurance
#
# Home Insurance +−
#
#
#
#
#
# Home Insurance
#
#
# Alberta Home Insurance
#
#
# Condo Insurance
#
#
# Tenant Insurance
#
#
# Ontario Home Insurance
#
#
# BC Home Insurance
#
#
# Contents Insurance
#
#
#
#
#
#
#
#
# Business Insurance
#
# Business Insurance +−
#
#
#
#
#
# Commercial Auto
#
#
# Commercial Property
#
#
#
#
#
#
# General Liability
#
#
# Professional
#                                         Liability
#
#
# General Contractor Insurance
#
#
# Pet Care Insurance
#
#
# Small Business Insurance
#
#
# Personal Services
#                                         Insurance
#
#
#
#
#
#
#
# Mortgage Rates
#
# Mortgage Rates +−
#
#
#
#
#
# Best Mortgage Rates
#
#
# Alberta Mortgage Rates
#
#
# Ontario Mortgage Rates
#
#
# British Columbia Mortgage Rates
#
#
#
#
#
#
#
# Credit Cards
#
# Credit Cards +−
#
#
#
#
#
# Best Credit Cards
#
#
# Rewards Credit Cards
#
#
# Low Interest Credit Cards
#
#
# Business Credit Cards
#
#
# Travel Credit Cards
#
#
#
#
#
#
# Balance Transfer Credit Cards
#
#
# Credit Card Guides
#
#
# Cash Back Credit Cards
#
#
# Student Credit Cards
#
#
# Travel Insurance Credit Cards
#
#
#
#
#
#
# No Fee Credit Cards
#
#
# No Foreign Transaction Fees
#                                         Credit Cards
#
#
# Secured Credit Cards
#
#
# Special Offers
#
#
#
#
#
#
#
#
#
#
#
# Check Your Application Status
#
#
#
#
#
#
#
#
#
#
# More Options
#
# More Options +−
#
#
#
# Travel Insurance
#
#
# Travel Insurance
#
#
# Visitors to Canada
#
#
# International Students
#                                         Travel Insurance
#
#
# Super Visa
#
#
# Snowbird Insurance
#
#
#
#
# Life Insurance
#
#
# Life Insurance
#
#
#
#
# Other Products
#
#
# Motorcycle Insurance
#
#
#
#
# Banking
#
#
# Savings Accounts
#
#
# Chequing Accounts
#
#
# Senior Accounts
#
#
# Children's Accounts
#
#
# TFSAs
#
#
#
#
# Investing
#
#
# GICs
#
#
# RRSPs
#
#
#
#
#
#
#
#  Resources
#
# Resources +−
#
#
#
# Car Insurance Resources
#
#
# Rates by Location
#
#
# Insurance Guides
#
#
# Insurance Calculator
#
#
# Ontario Rate Tracker
#
#
# Alberta Rate Tracker
#
#
#
#
# Home Insurance Resources
#
#
# Rates by Location
#
#
# Home Insurance Guides
#
#
# Mortgage Resources
#
#
# Mortgage Calculators
#
#
# Mortgage Guides
#
#
# Mortgage Report 2024
#
#
#
#
# Credit Card Resources
#
#
# Credit Card Guides
#
#
#
#
#
#
#
#
#
#
# The Dot
# Your blog for tips, tricks and news
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
# Search
#
#
# Submit
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# You'll be redirected in a few seconds. Please don't exit this window.
#
#
#
# We are now transferring you to LowestRates.ca to complete your quote.
# If you are not redirected within 30 seconds, please click here to continue.
#
#
#
#
#
#
#
#
# Quebec
# If you are looking for a car insurance quote in Quebec, you will be directed to Click Insurance, where you will be able to compare quotes from top insurance companies in that province.
#
# Continue
#
#
#
#
#
#
#
#
# You'll be redirected in a few seconds. Please don't exit this window.
#
#
#
# We are now transferring you to NFP Insurance to complete your quote. If you are not redirected within 30 seconds, click here to continue.
#
#
#
#
#
#
#
#
# Motorcycle Insurance
# If you are looking for a motorcycle insurance quote in Ontario, you will be directed to NFP Insurance, where you can compare your options with a licensed insurance professional.
#
# Continue
#
#
#
#
#
#
#
#
# Nous sommes là pour vous aider
# Malheureusement, notre site n’est pas en capacité de vous proposer une soumission en ligne en français pour le moment. Toutefois, vous pouvez nous contacter afin qu’un agent francophone vous assiste dans votre recherche du meilleur prix.
# 1-888-854-2503
#
# Continuer sur la version en Anglais
#
#             Lundi – Vendredi: 8h - 20h HAE
#             Samedi: 10h – 16h HAE
#
#
#
#
#
#
#
#
#
# You'll be redirected in a few seconds. Please don't exit this window.
#
#
#
# We are now transferring you to Lussier Insurance to complete your quote.
# If you are not redirected within 30 seconds, please click here to continue.
#
#
#
#
#
#
#
#
# Quebec
# If you are looking for a car insurance quote in Quebec, you will be directed to Lussier Insurance, where you will be able to compare quotes from top insurance companies in that province.
#
# Continue
#
#
#
#
#
#
#
#
# Quebec
# Si vous recherchez une soumission pour une assurance auto au Québec, nous allons vous connecter avec l’un de nos partenaires dans ce secteur.​
#
# Continuer
#
#
#
#
#
#
#
#
#
# Quebec
# If you are looking for a property insurance quote in Quebec, you will be directed to Click Insurance, where you will be able to compare quotes from top insurance companies in that province.
#
# Continue
#
#
#
#
#
#
#
#
# Quebec FR
# If you are looking for a property insurance quote in Quebec, you will be directed to Click Insurance, where you will be able to compare quotes from top insurance companies in that province.
#
# Continue
#
#
#
#
#
#
#
#
# You'll be redirected in a few seconds. Please don't exit this window.
#
#
#
# We are now transferring you to Click Insurance to complete your quote.
# If you are not redirected within 30 seconds, please click here to continue.
#
#
#
#
#
#
#
#
# If you are looking for a travel insurance quote and reside in Quebec, you will be connected with one our dedicated insurance partners offering quotes in that area.​
#
# Continue
#
#
#
#
#
#
#
#
# Si vous recherchez une soumission pour une assurance voyage et résidez au Québec, nous allons vous connecter avec l’un de nos partenaires dans ce secteur.​
#
#
# Continuer
#
#
#
#
#
#
#
#
#
# If you are looking for a life insurance quote and reside in Quebec, you will be connected with one our dedicated insurance partners offering quotes in that area.​
#
#
# Continue
#
#
#
#
#
#
#
#
#
# If you are looking for a home insurance quote in British Columbia, you will be connected with one of our dedicated insurance partners offering quotes in that area.​
#
#
# Continue
#
#
#
#
#
#
#
#
#
# You’ll be redirected in a few seconds. Please don’t exit this window.
#
#
#
#
#
#
#
#
#
#
#
#
# We are now transferring you to LowestRates.ca to complete your quote.
# If you are not redirected within 30 seconds, please click here to continue.
#
#
#
#
#
#
#
#
#
# Compare life insurance quotes
# If you are looking for a life insurance quote, you will be directed to LowestRates.ca, part of the RATESDOTCA Group Ltd family of companies, where you will be able to compare quotes from top Canadian insurance companies.
#
# Continue
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2024's Best Travel Credit Cards for Canadians
#
#
# Love to travel? Make travelling more affordable by earning travel rewards with a travel credit card.
#
#
#
#
#
#
#
#
#
#
# Select your priority
#
#
#
#
#
#
#
#
#  Rewards
#
#  Low Interest
#
#
#
#
#
#
#
#
#
#
#
#
# Select your rewards preference
#
#
#
#
#
#
#
#
# Cash+
#
# Travel
#
# Both
#
#
#
#
#
#
#
#
#
#
#
#
#  Select your annual fees
#
#
#
#
#
#
#
#
# No Fees
#
# I Don't Mind
#
#
#
#
#
#
#
#
#
# See My Cards
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Best of Finance Winners for 2024: Best Travel Credit Cards
#
#
#
#
#
#
#
#
#
#
#
#
# First-year value*
# Credit score required
# Winner
#
#
#
#
#
#
# Best Overall Travel Credit Card
#
# $1,536
# Excellent
# CIBC Aventura® Visa Infinite™ Card
#
#
#
# Best Credit Card for Earning Travel Points
#
# $1,361
# Fair
# American Express Cobalt® Credit Card
#
#
#
# Best Credit Card with No Foreign Transaction Fees
#
# $1,194
# Good
# Scotiabank®* Gold American Express® Card
#
#
#
# Best No-Fee Travel Credit Card
#
# $545
# Good
# MBNA Rewards Platinum Plus® Mastercard®
#
#
#
#
#
#
#
#
#
#
#
# *The RATESDOTCA Best of Finance methodology assumes the cardholder spends an average of $2,000 a month on their card to determine the first-year value. The calculation includes all welcome bonuses and promotional offers at the time of publishing.
#
#
#
#
#
#
#
#
# Best Overall Travel Credit CardWith travel resuming all around the globe, having the best travel rewards credit card can help you earn rewards for everyday purchases and redeem them for flights, hotel stays and vacation packages.Many travel credit cards also feature great additional perks, like shopping coverage, mobile device insurance and exclusive offers.We compared the top travel credit cards using our Best of Finance methodology and ranked the cards that provided the highest first-year value.
#
#
#
#
#
#
#
#
#
#
#
#
# First-year value
# Credit score required
# Top features
#
#
#
#
#
#
# WINNERCIBC Aventura® Visa Infinite™ Card
#
# $1,536
# Excellent
# NEXUS Application Fee Rebate, complimentary lounge visits, and travel insurance
#
#
#
# Runner upRBC Avion® Visa Infinite
#
# $1,144
# Good
# Complimentary DoorDash subscription, instant fuel savings, and comprehensive travel insurance
#
#
#
# Runner upTD® Aeroplan® Visa Infinite* Card
#
# $1,370
# Good
# Free first checked bag, NEXUS rebate, auto membership and travel insurance
#
#
#
#
#
#
#
#
#
#
#
# Winner: CIBC Aventura® Visa InfiniteTM CardCardholders of the CIBC Aventura® Visa InfiniteTM Card can access loads of travel perks, from four free annual airport lounge passes to a NEXUS application fee rebate every four years. This card also features travel insurance and Visa Infinite benefits, such as complimentary breakfast at over 900 properties worldwide and exclusive tours of Wine Country.Pay no booking fees through the Aventura Travel Assistant and use points to cover airfare costs, including taxes and fees.According to our Best of Finance methodology, the average Canadian would earn around $1,536 in rewards in the first year.
#
#
#
#
#
#
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                 + Welcome bonus
#
#
#                 $900
#
#
#
#
#                 + Annual rewards
#
#
#                   $636
#
#
#
#
#                 - Annual fee
#
#                 (First Year Rebated†)
#
#
#
#                   $0
#
#
#
#
#
#
#                 Total first year value
#
#
#
#                   $1536
#
#
#
#
#
#
#
#
#
#             First year value
#
#
#                 $1536
#
#
#
#
#
#
#
#
#             CIBC Aventura® Visa Infinite*
#
#
#
#
#
#
#
#
#
#
#               Welcome bonus
#
#
#               $900
#
#
#               CIBC Aventura Rewards points
#
#
#
#
#
#               Annual rewards
#
#
#               $636
#
#
#               CIBC Aventura Rewards points
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $139
#
#
#                 (First Year Rebated†)
#
#
#
#
#
#               Interest rates:
#
#
#
#                 20.99%
#
#               on purchases •
#
#                 22.99%
#
#               on cash advances
#
#
#
#
#
#
# This offer is not available for residents of Quebec.
# 2024 Winner  – Best Overall Travel Credit Card and Best Overall Visa Credit Card
# Earn points on all purchases and redeem on travel or statement credits
#
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#             Top 5 Perks
#
#
#  Trip Cancellation Insurance† - $1,500 Trip Interruption Insurance† - $2,000 Mobile Device Insurance† -$1,000 Elevate your airport experience with 4 complimentary visits at 1,200+ lounges globally through Visa Airport Companion Program: up to $277 in value.† Save on gas with CIBC and Journie Rewards†
#
#
#
#
#
#             Reward Structure
#
#
# Welcome Offer:  Join and get up to $1,450 in value including a first year annual fee rebate!†    CIBC Aventura Rewards points:  2 points for every $1 spent on travel purchased through the CIBC Rewards Centre† 1.5 points for every $1 spent at eligible gas stations, EV charging, grocery stores and drug stores† 1 point for every $1 spent on all other purchases†
#
#
#
#
#
#             Criteria
#
#
#  Personal Income:  $60,000† Household Income:  $100,000† Credit Score: Excellent (≥720) Canadian Resident Reached Provincial Age of Majority
#
#
#
#
#
# Learn more
#
#
#
#
#               Apply now
#
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
# CIBC Aventura® Visa Infinite*
#
#
#
#
#
#
#
#
#
#
#                 Welcome bonus
#
#
#                 $900
#
#
#
#
#
#                   Annual rewards
#
#
#
#                 $636
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                       + Welcome bonus
#
#
#                       $900
#
#
#
#
#                       + Annual rewards
#
#
#                         $636
#
#
#
#
#                       - Annual fee
#
#                       (First Year Rebated†)
#
#
#
#                         $0
#
#
#
#
#
#
#                       Total first year value
#
#
#
#                         $1536
#
#
#
#
#
#
#
#                   First year value
#
#
#
#                     $1536
#
#
#
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $139
#
#
#                 (First Year Rebated†)
#
#
#
#
#
#               Interest rates:
#
#
#
#
#                   20.99%
#
#                 on purchases
#
#
#
#                   22.99
#
#                 on cash advances
#
#
#
#
#
#
#
# This offer is not available for residents of Quebec.
# 2024 Winner  – Best Overall Travel Credit Card and Best Overall Visa Credit Card
# Earn points on all purchases and redeem on travel or statement credits
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#               Top 5 Perks
#
#
#
#  Trip Cancellation Insurance† - $1,500 Trip Interruption Insurance† - $2,000 Mobile Device Insurance† -$1,000 Elevate your airport experience with 4 complimentary visits at 1,200+ lounges globally through Visa Airport Companion Program: up to $277 in value.† Save on gas with CIBC and Journie Rewards†
#
#
#
#
#
#
#               Reward Structure
#
#
#
# Welcome Offer:  Join and get up to $1,450 in value including a first year annual fee rebate!†    CIBC Aventura Rewards points:  2 points for every $1 spent on travel purchased through the CIBC Rewards Centre† 1.5 points for every $1 spent at eligible gas stations, EV charging, grocery stores and drug stores† 1 point for every $1 spent on all other purchases†
#
#
#
#
#
#
#               Criteria
#
#
#
#  Personal Income:  $60,000† Household Income:  $100,000† Credit Score: Excellent (≥720) Canadian Resident Reached Provincial Age of Majority
#
#
#
#
# Learn more
#
#
#             Apply now
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
#
#
#
# Annual fee$139 (First year rebated)Interest ratePurchase – 20.99%Cash advance – 22.99% (21.99% for QC residents)Balance transfer – 22.99%Welcome bonusGet a total of up to 45,000 Aventura points (up to $900 in travel value†) during your first year15,000 Aventura points when you make your first purchase†30,000 Aventura Points when you spend $3,000 or more in the first 4 monthly statement periods†Get a one-time annual fee rebate ($139) for you (the primary cardholder) and up to three authorized users ($50 each): over $189 value†Elevate your airport experience with 4 complimentary visits at 1,200+ lounges globally through Visa Airport Companion Program: over $190 in value.†Plus, get a NEXUS◊ Application Fee rebate†: a $50 value†Offer expiry date: N/A - Offer subject to changeRewardsEarn two points for every $1 spent on travel through the CIBC Rewards Centre.Earn 1.5 points for every $1 spent at eligible gas stations, grocery stores and drugstores.Earn one point for every $1 spent on all other purchases.Earning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period = $1,525 Annual fee = $139 (First year rebated)Interest rate = Purchase – 20.99%, Cash advance – 22.99% (21.99% for QC residents), Balance transfer – 22.99%Total earned over a 12-month period (rewards minus annual fee) = $1,525BenefitsAccess to the Aventura Travel AssistantAccess to the Visa Infinite Travel program and the Visa Infinite Concierge servicesNEXUS application fee rebate once every 4 years.Insurance Travel insurance with out-of-province emergency travel medical coverageTrip cancellation/trip interruption insuranceCar rental collision/loss damage insuranceFlight delay and baggage insuranceHotel burglary insurance chargeMobile device insurance
#
#
#
#
#
#
#
#
#
# Runners-up: Best Overall Travel Credit Card
#
#
#
#
#
# RBC Avion® Visa Infinite
#
#
#
# With the RBC Avion® Visa Infinite, you can earn reward points and redeem them for a variety of great rewards such as travel tickets, gift cards, merchandise or cash back. As a cardholder, you have no blackouts or seat restrictions. If you find an open seat, you can use your rewards to book it – even during peak seasons. Best of all, flights start as low as 15,000 RBC rewards points.According to our Best of Finance methodology, the average Canadian could earn around $1,144 in rewards in the first year.Annual fee$120Limited time offer/bonus:   Get 35,000 welcome Avion points on approval** (travel value of up to $750†)- Enough to fly anywhere in Canada & the U.S† (Alaska and Hawaii require more points.Offer Expiry Date: N/A - Ongoing Offer. RewardsEarn one RBC Rewards point for every $1 spent on the card.Earn an extra 25% on eligible travel-related purchases.Earn an extra 20% at Petro-Canada.
#
#
#
#
# TD®  Aeroplan® Visa Infinite* Card
#
#
#
# Get Air Canada benefits with the TD® Aeroplan® Visa Infinite* Card, including some shared perks for travelling companions. Access travel insurance and exclusive Visa Infinite benefits like the Visa Infinite Luxury Hotel Collection and Visa Infinite Wine Country Program for savings and upgrades.Plus, get a NEXUS application fee rebate every 48 months when you enroll. This benefit also applies to additional cardholders.According to our Best of Finance methodology, the average Canadian could earn around $1,370 in rewards in the first year.Annual fee$139 (First year rebated†)Limited time offer/bonusEarn up to 40,000 Aeroplan points. Get 10,000 Aeroplan points when you make your first purchase.† Get 15,000 Aeroplan points if you spend $7,500 within 180 days of opening your account.† Plus, earn a one-time anniversary bonus of 15,000 Aeroplan points when you spend $12,000 within 12 months of Account opening†Terms and Conditions†Terms and conditions apply. This offer is not available for residents of Quebec. For Quebec residents, please click here.Offer expiry date: January 6, 2025RewardsEarn 1.5 points for every $1 spent on eligible gas, grocery and direct through Air Canada® purchases†.Earn one point for every $1 spent on all other purchases.†
#
#
#
#
#
#
#
#
#
#
#
#
#
# Back to top
#
#
#
#
#
#
#
#
# Best Credit Card for Earning Travel PointsTravel programs typically offer the best redemption value of all rewards credit cards. Whether they offer rewards, points or miles, these cards will always provide more value than cashback cards (even if the flexibility the latter provides is nice to have). Most programs allow members to redeem rewards for flights, vacation packages, upgrades and other travel savings. Some programs also allow point conversions to other popular travel programs. Additionally, many of our top picks feature insurance coverage and exclusive offers like lounge access or benefits at hotels and resorts. We compared Canada’s leading travel credit cards and ranked them according to first-year value.
#
#
#
#
#
#
#
#
#
#
#
#
# First-year value
# Credit score required
# Top features
#
#
#
#
#
#
# WINNERAmerican Express Cobalt® Credit Card
#
# $1,361
# Fair
# Flexible rewards points + travel insurance.
#
#
#
# Runner upScotiabank®* Gold American Express® Card
#
# $1,194
# Good
# High rewards rates and great travel perks such as no foreign exchange fees and travel insurance.
#
#
#
# Runner upCIBC Aventura® Visa Infinite* Card
#
# $1,536
# Excellent
# Generous welcome offer and NEXUS fee rebate.
#
#
#
#
#
#
#
#
#
#
#
# Winner: American Express Cobalt® Credit CardThe American Express Cobalt® Credit Card is one of the best cards for amassing rewards, offering cardholders five points for every $1 spent on restaurants and food deliveries, three points for every $1 spent on eligible streaming subscriptions, two points for every $1 spent on eligible travel and transit and one point for every $1 spent anywhere else. Not only that, but the Membership Rewards® program is incredibly flexible, allowing members to redeem points for almost anything — travel, merchandise and more. Eligible cards, including the American Express Cobalt® Credit Card, can access the Fixed Points Travel Program and American Express Travel Online for travel offers and special rates. Cardholders can even use Membership Rewards® to pay for taxes, fees and carrier surcharges. According to our Best of Finance methodology, the average Canadian could earn around $1,361 in rewards in the first year.
#
#
#
#
#
#
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                 + Welcome bonus
#
#
#                 $362
#
#
#
#
#                 + Annual rewards
#
#
#                   $1155
#
#
#
#
#                 - Annual fee
#
#
#
#
#
#
#                   $156
#
#
#
#
#
#
#                 Total first year value
#
#
#
#                   $1361
#
#
#
#
#
#
#
#
#
#             First year value
#
#
#                 $1361
#
#
#
#
#
#
#
#
#             American Express Cobalt®  Credit Card
#
#
#
#
#
#
#
#
#
#
#               Welcome bonus
#
#
#               $362
#
#
#               AMEX Rewards points
#
#
#
#
#
#               Annual rewards
#
#
#               $1155
#
#
#               AMEX Rewards points
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $156
#
#
#
#
#
#               Interest rates:
#
#
#
#                 21.99%
#
#               on purchases •
#
#                 21.99%
#
#               on cash advances
#
#
#
#
#
#
# 2024 Winner – Best Overall Rewards Credit Card, Best Credit Card for Young Professionals, and Best Credit Card for Earning Travel Points and Best American Express Credit Card.
#  Particularly great for individuals who live in the city, eat out often or order in.
#
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#             Top 5 Perks
#
#
#  Cobalt Perks Program and AMEX ticket offers/exclusive accessEnjoy access to hotel bookings, a room upgrade (when available), 12pm check-in and late check-out (when available), and up to $100 USD hotel credit to use on amenities when charged to the room for a stay of 2 or more consecutive nights through The Hotel Collection from American Express Travel Mobile Device Insurance - $1,000 Flight Delay - $500 Access Front Of The Line® Amex Presale & Reserved Tickets to some of your favourite concerts and theatre performances and special offers and events curated for Cardmembers with Amex ExperiencesTM
#
#
#
#
#
#             Reward Structure
#
#
# Welcome Offer:  In your first year as a new Cobalt Cardmember, you can earn 1,250 Membership Rewards® points for each monthly billing period in which you spend $750 in net purchases on your Card. This could add up to 15,000 points in a year. That’s up to $150 towards a weekend getaway or concert tickets    AMEX Rewards Points:  5x the points on eligible eats and drinks in Canada, including groceries and food delivery. Spend caps apply 3x the points on eligible streaming subscriptions in Canada 2 points for every $1 spent on eligible transit & gas purchases in Canada 1 additional point on eligible hotel and car rental bookings via American Express Travel Online 1x points for every $1 in card purchases everywhere else
#
#
#
#
#
#             Criteria
#
#
#  Personal Income: NA Household Income: NA Credit Score: Fair (<660) Canadian Resident Provincial Age of Majority
#
#
#
#
#
# Learn more
#
#
#
#
#               Apply now
#
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
# American Express Cobalt®  Credit Card
#
#
#
#
#
#
#
#
#
#
#                 Welcome bonus
#
#
#                 $362
#
#
#
#
#
#                   Annual rewards
#
#
#
#                 $1155
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                       + Welcome bonus
#
#
#                       $362
#
#
#
#
#                       + Annual rewards
#
#
#                         $1155
#
#
#
#
#                       - Annual fee
#
#
#
#
#
#
#                         $156
#
#
#
#
#
#
#                       Total first year value
#
#
#
#                         $1361
#
#
#
#
#
#
#
#                   First year value
#
#
#
#                     $1361
#
#
#
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $156
#
#
#
#
#
#               Interest rates:
#
#
#
#
#                   21.99%
#
#                 on purchases
#
#
#
#                   21.99
#
#                 on cash advances
#
#
#
#
#
#
#
# 2024 Winner – Best Overall Rewards Credit Card, Best Credit Card for Young Professionals, and Best Credit Card for Earning Travel Points and Best American Express Credit Card.
#  Particularly great for individuals who live in the city, eat out often or order in.
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#               Top 5 Perks
#
#
#
#  Cobalt Perks Program and AMEX ticket offers/exclusive accessEnjoy access to hotel bookings, a room upgrade (when available), 12pm check-in and late check-out (when available), and up to $100 USD hotel credit to use on amenities when charged to the room for a stay of 2 or more consecutive nights through The Hotel Collection from American Express Travel Mobile Device Insurance - $1,000 Flight Delay - $500 Access Front Of The Line® Amex Presale & Reserved Tickets to some of your favourite concerts and theatre performances and special offers and events curated for Cardmembers with Amex ExperiencesTM
#
#
#
#
#
#
#               Reward Structure
#
#
#
# Welcome Offer:  In your first year as a new Cobalt Cardmember, you can earn 1,250 Membership Rewards® points for each monthly billing period in which you spend $750 in net purchases on your Card. This could add up to 15,000 points in a year. That’s up to $150 towards a weekend getaway or concert tickets    AMEX Rewards Points:  5x the points on eligible eats and drinks in Canada, including groceries and food delivery. Spend caps apply 3x the points on eligible streaming subscriptions in Canada 2 points for every $1 spent on eligible transit & gas purchases in Canada 1 additional point on eligible hotel and car rental bookings via American Express Travel Online 1x points for every $1 in card purchases everywhere else
#
#
#
#
#
#
#               Criteria
#
#
#
#  Personal Income: NA Household Income: NA Credit Score: Fair (<660) Canadian Resident Provincial Age of Majority
#
#
#
#
# Learn more
#
#
#             Apply now
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
#
#
#
# Annual fee $156*Welcome bonusIn your first year as a new Cobalt Cardmember, you can earn 1,250 Membership Rewards® points for each monthly billing period in which you spend $750 in net purchases on your Card. This could add up to 15,000 points in a year. That’s up to $150 towards a weekend getaway or concert tickets.Rewards5x AMEX Membership Rewards (spend caps apply):GroceriesRestaurantsBarsFood Delivery3x AMEX Membership Rewards:Select streaming services2x AMEX Membership Rewards:Transit and Ride SharesGas1 additional AMEX Membership Reward:Eligible Hotel and Car Rental bookings via American Express Travel Online1x AMEX Membership Rewards:All other purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $1,155 + $362 = $1,517Annual fee = $156Total earned over a 12-month period (rewards minus annual fee) = $1,361BenefitsEnjoy access to hotel bookings, and up to $100 USD hotel credit to use on amenities when charged to the room for a stay of 2 or more consecutive nights through The Hotel Collection from American Express TravelAccess Front Of The Line® Amex Presale & Reserved Tickets to some of your favourite concerts and theatre performances and special offers and events curated for Cardmembers with Amex ExperiencesTMCobalt Cardmembers receive regular Perks such as bonus reward offers and access to great eventsTransfer points 1:1 to several frequent flyer and other loyalty programsInsurance coveragePurchase Protection - 90 daysExtended Warranty - 1 yearTravel Accident - $250,000Emergency Medical Term - 15 daysFlight Delay - $500Baggage Delay - $500Lost or Stolen Baggage - $500Hotel Burglary - $500Rental Car Theft & DamageMobile Device - $1,000
#
#
#
#
#
#
#
#
#
# Runners-up: Best Credit Card for Earning Travel Points
#
#
#
#
#
# Scotiabank®* Gold American Express® Card
#
#
#
# The Scotiabank®* Gold American Express® Card is great for travellers looking to use rewards to book their next vacation or make purchases abroad. This card is one of the few that offers no foreign transaction fees, meaning you’ll only pay the exchange rate and Amex won’t charge you for having to make the conversion.Earn five Scotia Scene+ points for every $1 spent on eligible groceries, dining in or out and entertainment purchases. Collect three Scotia Scene+ points for every $1 spent on gas, public transit or streaming services. Earn one Scotia Scene+ point per dollar spent on everything else.Based on our Best of Finance methodology, the average Canadian can earn $1,194 in Scotia Scene+ points within the first year.Annual fee $120 (First year waived)Welcome bonusEarn up to $950* in value in the first 12 months, including up to 45,000 bonus Scene+ points and first year annual fee waived.1 . Offer ends January 2, 2025.Rewards6x Scotia Scene+ points at select grocery stores5x Scotia Scene+ points from groceries, restaurants and entertainment3x Scotia Scene+ points from gas, daily transit and select streaming services1x Scotia Scene+ points for all other purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $744 + $450 = $1,194Annual fee = $120 (First year waived)Total earned over a 12-month period (rewards minus annual fee) = $1,194Want to learn more about how the Scotiabank®* Gold American Express® Card stands-up against the competition? Read more from our "In the Ring" series:In the Ring: American Express Cobalt Credit Card vs. Scotiabank Gold American Express Card
#
#
#
#
# CIBC Aventura® Visa Infinite* Card
#
#
#
# Cardholders of the CIBC Aventura® Visa Infinite Card can access loads of travel perks, from four free annual airport lounge passes to a NEXUS application fee rebate every four years. This card also features travel insurance and Visa Infinite benefits, such as complimentary breakfast at over 900 properties worldwide and exclusive tours of Wine Country.Pay no booking fees through the Aventura Travel Assistant and use points to cover airfare costs, including taxes and fees.According to our Best of Finance methodology, the average Canadian would earn around $1,536 in rewards in the first year.Annual fee $139 (first year rebated!)Welcome bonusJoin and get over $1,500 in value including a first year annual fee rebate!†Get a total of up to 45,000 Aventura Points (up to $900 in travel value):15,000 Aventura Points when you make your first purchase.30,000 Aventura Points when you spend $3,000 or more in the first 4 monthly statement periods.Get a one-time annual fee rebate ($139) for you (the primary cardholder) and up to three authorized users ($50 each): over $189 value.RewardsEarn:2 points for every $1 spent on travel purchased through the CIBC Rewards Centre1.5 points for every $1 spent at eligible gas stations and EV charging, grocery stores and drug stores1 point for every $1 spent on all other purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $636 + $900 = $1,536Annual fee = $156 (first year rebated!)Total earned over a 12-month period (rewards minus annual fee) = $1,536
#
#
#
#
#
#
#
#
#
#
#
#
#
# Back to top
#
#
#
#
#
#
#
#
# Best Credit Card With No Foreign Transaction FeesTravellers can forgo the foreign currency exchange line and pack a much smaller wallet for their next trip. These credit cards offer no foreign transaction fees on purchases, sparing cardholders the extra 1.5% to 3% providers typically charge. Only the exchange rate applies. Cardholders also get the added convenience of tracking all their transactions from little trips to the grocery store, tours and excursions all in one place. Plus, travellers won’t get stuck with extra foreign coins and bills at the end of their trip. These credit cards also feature various benefits and travel insurance to help make trips more comfortable and carefree. Spend points on flights, rental cars, hotel stays or merchandise and get the most out of your next adventure. We compared the top credit cards with no foreign transaction fees using our Best of Finance methodology and ranked the cards that provided the highest first-year value.
#
#
#
#
#
#
#
#
#
#
#
#
# First-year value
# Credit score required
# Top features
#
#
#
#
#
#
# WINNERScotiabank®* Gold American Express® Card
#
# $1,194
# Good
# Flexible Scotia rewards program + no foreign transaction fees.
#
#
#
# Runner-upScotiabank Passport™ Visa Infinite* Card
#
# $604
# Excellent
# Offers great insurance and a Priority Pass package, in addition to no foreign transaction fees.
#
#
#
# Runner-upHome Trust Preferred Visa* Card
#
# $240
# Good
# Includes purchase protection insurance and earns you 1% cash back rewards on every purchase, in addition to no foreign transaction fees.
#
#
#
#
#
#
#
#
#
#
#
# Winner: Scotiabank®* Gold American Express® CardThe Scotiabank®* Gold American Express® Card offers a great return on spending. Earn five Scotia Scene+ points for every $1 spent on groceries, restaurant, food delivery and entertainment purchases. Get three Scotia Scene+ points for every $1 spent on gas, daily transit purchases and select streaming services and earn one Scotia Scene+ point for every $1 spent everywhere else.Cardholders pay no foreign transaction fees on foreign currency purchases, typically around 2.5%. Only the exchange rate applies. Plus, access discounts through the Scotia Rewards Travel Service and get a wide range of travel insurance through the card.According to our Best of Finance methodology, the average Canadian would earn around $1,194 in rewards in the first year.
#
#
#
#
#
#
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                 + Welcome bonus
#
#
#                 $450
#
#
#
#
#                 + Annual rewards
#
#
#                   $744
#
#
#
#
#                 - Annual fee
#
#
#                 (First Year Waived)
#
#
#
#                   $0
#
#
#
#
#
#
#                 Total first year value
#
#
#
#                   $1194
#
#
#
#
#
#
#
#
#
#             First year value
#
#
#                 $1194
#
#
#
#
#
#
#
#
#             Scotiabank®* Gold American Express® Card
#
#
#
#
#
#
#
#
#
#
#               Welcome bonus
#
#
#               $450
#
#
#               Scotia Scene+ Points
#
#
#
#
#
#               Annual rewards
#
#
#               $744
#
#
#               Scotia Scene+ Points
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $120
#
#
#
#                   (First Year Waived)
#
#
#
#
#
#
#               Interest rates:
#
#
#
#                 20.99%
#
#               on purchases •
#
#                 22.99%
#
#               on cash advances
#
#
#
#
#
#
# 2024 Winner – Best No Foreign Transaction Fees Credit Card for Long Stay Travellers and Best Credit Card for Subscriptions
#
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#             Top 5 Perks
#
#
#  No foreign transaction fees - including online shopping Emergency Medical Term - 25 days Trip Cancellation - $1,500 Trip Interruption - $1,500Amex Invites and reserved tickets access
#
#
#
#
#
#             Reward Structure
#
#
# Welcome Offer:  Earn up to $950* in value in the first 12 months, including up to 45,000 bonus Scene+ points. . Offer ends January 2, 2025.    Scotia Scene+ points:  6 points for every $1 you spend at Sobeys, IGA, Safeway, Foodland, FreshCo, Voilà by Sobeys, Voilà by IGA, Voilà by Safeway, Chalo! FreshCo, Thrifty Foods, IGA West, Les Marchés Tradition, Rachelle Béry and Co-Op 5 points for every $1 you spend at eligible grocery stores, dining and entertainment 3 points for every $1 you spend at eligible gas stations, daily transit, and select streaming services 1 point for every $1 you spend on all other eligible everyday purchases in any currency See terms and conditions for further details click here.
#
#
#
#
#
#             Criteria
#
#
#  Personal Income: $12,000 Household Income: NA Credit Score: Good (660+) Canadian Resident Provincial Age of Majority
#
#
#
#
#
# Learn more
#
#
#
#
#               Apply now
#
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
# Scotiabank®* Gold American Express® Card
#
#
#
#
#
#
#
#
#
#
#                 Welcome bonus
#
#
#                 $450
#
#
#
#
#
#                   Annual rewards
#
#
#
#                 $744
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                       + Welcome bonus
#
#
#                       $450
#
#
#
#
#                       + Annual rewards
#
#
#                         $744
#
#
#
#
#                       - Annual fee
#
#
#                       (First Year Waived)
#
#
#
#                         $0
#
#
#
#
#
#
#                       Total first year value
#
#
#
#                         $1194
#
#
#
#
#
#
#
#                   First year value
#
#
#
#                     $1194
#
#
#
#
#
#
#
#
#
#               Annual fees:
#
#
#
#                 $120
#
#
#
#                   (First Year Waived)
#
#
#
#
#
#
#               Interest rates:
#
#
#
#
#                   20.99%
#
#                 on purchases
#
#
#
#                   22.99
#
#                 on cash advances
#
#
#
#
#
#
#
# 2024 Winner – Best No Foreign Transaction Fees Credit Card for Long Stay Travellers and Best Credit Card for Subscriptions
#
#
#
#               Apply now
#
#
#
#
#
#
#
#
#               Top 5 Perks
#
#
#
#  No foreign transaction fees - including online shopping Emergency Medical Term - 25 days Trip Cancellation - $1,500 Trip Interruption - $1,500Amex Invites and reserved tickets access
#
#
#
#
#
#
#               Reward Structure
#
#
#
# Welcome Offer:  Earn up to $950* in value in the first 12 months, including up to 45,000 bonus Scene+ points. . Offer ends January 2, 2025.    Scotia Scene+ points:  6 points for every $1 you spend at Sobeys, IGA, Safeway, Foodland, FreshCo, Voilà by Sobeys, Voilà by IGA, Voilà by Safeway, Chalo! FreshCo, Thrifty Foods, IGA West, Les Marchés Tradition, Rachelle Béry and Co-Op 5 points for every $1 you spend at eligible grocery stores, dining and entertainment 3 points for every $1 you spend at eligible gas stations, daily transit, and select streaming services 1 point for every $1 you spend on all other eligible everyday purchases in any currency See terms and conditions for further details click here.
#
#
#
#
#
#
#               Criteria
#
#
#
#  Personal Income: $12,000 Household Income: NA Credit Score: Good (660+) Canadian Resident Provincial Age of Majority
#
#
#
#
# Learn more
#
#
#             Apply now
#
#
#
#
#
#  Details at a glance
#
#
#  Collapse details
#
#
#
#
#
#
#
#
#
#
#
# Annual fee $120 (First year waived)Welcome bonusEarn up to $950* in value in the first 12 months, including up to 45,000 bonus Scene+ points and first year annual fee waived.1 . Offer ends January 2, 2025.Rewards6x Scotia Scene+ points:Select grocery stores5x Scotia Scene+ points:GroceriesRestaurantsEntertainment3x Scotia Scene+ points:GasDaily transitSelect streaming services1x Scotia Scene+ point:All other purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $744 + $450 = $1,194Annual fee = $120*Total earned over a 12-month period (rewards minus annual fee) = $1,194BenefitsNo foreign transaction fees - including online shoppingAmex exclusive benefits (Front Of The Line)24/7 concierge serviceDiscount on the Priority Pass membershipInsurance coveragePurchase Protection - 90 daysExtended Warranty - 1 yearTravel Accident - $500,000Emergency Medical Term - 25 daysTrip Cancellation - $1,500Trip Interruption - $1,500Flight Delay- $500Baggage Delay - $1,000Lost or Stolen Baggage - $1,000Rental Car Theft & Damage
#
#
#
#
#
#
#
#
#
# Runners-up: Best Credit Card With No Foreign Transaction Fees
#
#
#
#
#
# Scotiabank Passport™ Visa Infinite* Card
#
#
#
# The Scotiabank Passport™ Visa Infinite* Card can earn you up to 35,000 bonus Scotia Scene+ points and the $150 annual fee waived in the first year. Regularly earn two Scotia Scene+ points for every $1 spent on eligible grocery, dining, entertainment and daily transit purchases. Get one Scotia Scene+ point for every $1 spent everywhere else.Cardholders can access an array of Visa Infinite exclusive offers and collections, as well as a full suite of travel services. Not only that, but this card also offers no foreign transaction fees and several complimentary memberships to help make travel more convenient and comfortable.According to our Best of Finance methodology, the average Canadian would see around $604 in Scotia Scene+ points within the first year.Annual fee $150 (first year waived)Welcome bonusEarn up to $1,100+ in value in the first 12 months, including up to 35,000 bonus Scene+ points. Offer ends January 2, 2025.Rewards3 Scotia Scene+ Points earned for every $1 spent at on:Select grocery stores2 Scotia Scene+ Points earned for every $1 spent at on:GroceriesDiningEntertainmentTransit1x Scotia Scene+ Point:All other purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $354 + $350 = $604Annual fee = $150 (waived in the first year)Total earned over a 12-month period (rewards minus annual fee) = $604
#
#
#
#
# Home Trust Preferred Visa Card
#
#
#
# The Home Trust Preferred Visa Card offers no foreign transaction fees on purchases made in foreign currency, which can save cardholders money abroad and online. Plus, cardholders get 1% cash back on all eligible purchases without category restrictions or limits to how much they can earn.According to our Best of Finance methodology, the average Canadian would earn just under $240 within the first year.Annual fee $0RewardsReceive: 1% cash back earn on all eligible purchasesEarning potentialHow does this card stack up to other rewards credit cards? We crunched the numbers using our Best of Finance methodology to see how much an average Canadian could earn over a 12-month period.Rewards earned over a 12-month period + Welcome Bonus = $240 + $0 = $240Annual fee = $0Total earned over a 12-month period (rewards minus annual fee) = $240Benefits0% foreign currency conversion charge on purchases abroad.Insurance coveragePurchase Protection - 90 days
#
#
#
#
#
#
#
#
#
#
#
#
#
# Back to top
#
#
#
#
#
#
#
#
# Best No-Fee Travel Credit CardAccess the top travel rewards programs with these no-fee cards. While this batch of cards have slightly lower earn rates than their counterparts with a fee, they still provide excellent value and great perks. Plus, these cards can slide into your wallet as a primary or secondary credit card, and you don’t have to worry about another annual expense. You can use the card as often or sparingly as you like without having to justify its worth. We compared the top no-fee travel credit cards using our Best of Finance methodology and ranked the cards that provided the highest value while also considering additional complimentary travel perks and benefits.
#
#
#
#
#
#
#
#
#
#
#
#
# First year value*
# Annual fee
# Top features
#
#
#
#
#
#
# WINNERMBNA Rewards Platinum Plus® Mastercard®
#
# $645
# $0
# Earn 4 points†† for every $1 spent on eligible restaurant, grocery, digital media, membership and household utility purchases during the first 90 days (until $10,000 is spent annually in the applicable category)
#
#
#
# Runner upCIBC Aventura Visa Card
#
# $527
# $0
# Earn 1 Aventra point for every $1 spend on gas, EV charging, groceries and drugstore purchases
#
#
#
# Runner upScotiabank American Express Card
#
# $434
# $0
# Earn 2 points for each $1 spend on a wide variety of categories
#
#
#
#
#
#
#
#
#
#
#
# Winner: MBNA Rewards Platinum Plus® Mastercard®The MBNA Rewards Platinum Plus® Mastercard® offers cardholders four points for every $1 spent on eligible grocery, restaurant, digital media, membership, and household utility purchases for the first 90 days, up to $10,000 in each category. After, earn two points for every $1 spent in these categories ($10,000 annual cap in each category) and one point for every $1 spent on all other purchases.This card also features $1,000,000 travel accident insurance, unexpected return home insurance and car rental accident insurance.According to our Best of Finance methodology, the average Canadian would earn around $545 in rewards in the first year.
#
#
#
#
#
#
#
#
#
#
# The estimated dollar amount of benefits you’ll accumulate based on your monthly spending and rewards preference
#
#
#
#                 + Cash bonus
#
#
#                 $100
#
#
#
#
#                 + Welcome bonus
#
#
#                 $205
#
#
#
#
#                 + Annual rewards
#
#
# ...
#
#
#
#
#
#
#
#
# RATESDOTCA may receive compensation when you click on links to those products or services. However, our content and calculations are objective and free from bias. The opinions expressed are purely those of RATESDOTCA; thus, partners are not responsible for any editorials or reviews that may appear. For current term and conditions on any advertiser or partner’s product, please visit their website.
#
#
#
#
#
#
#
#
# Best credit cards in other categoriesAll the Best Credit Cards in CanadaBest No-Fee Cash Back Credit CardBest No-Fee Travel Credit CardBest Overall Cash Back Credit CardBest Low Interest Credit CardBest Balance Transfer Credit CardBest Secured Credit Card for Building CreditBest Credit Card for Young ProfessionalsBest Student Credit CardBest Credit Card With No Foreign Transaction FeesBest Family Credit Card for Gas and GroceriesBest Credit Card for SubscriptionsBest No-Frills Cash Back Credit Card
#
#
#
#
#
#
#
# Latest credit card articles
#
#
#
#
#
#
#
#
#
# This year's best rewards credit cards for groceries
#
#
#
#
#                     Learn the best credit cards for grocery store purchases and rewards.
#
#
#
#
#
#                         4 mins read
#
#
#
#
#
#
#
#                             Aya A.
#
#
#
#
#
#                             Aug.30.24
#
#
#
#
#
#
#
#
#
#
#
#
# Top 3 credit cards with roadside assistance in Canada for 2024
#
#
#
#
#                     Roadside assistance can help you with your car troubles — and with some credit cards, you can get it for free. Learn about the best plans for you.
#
#
#
#
#
#                         7 mins read
#
#
#
#
#
#
#
#                             Hayley O.
#
#
#
#
#
#                             Aug.07.24
#
#
#
#
#
#
#
#
#
#
#
#
# Is credit card balance protection insurance worthwhile?
#
#
#
#
#                     If you’re a credit cardholder, you’ve probably been offered balance protection insurance before. But is it worth it? Here's what you need to know.
#
#
#
#
#
#                         2 mins read
#
#
#
#
#
#
#
#                             Aya A.
#
#
#
#
#
#                             Jul.11.24
#
#
#
#
#
#
#
#
#
#
#
#
#         Find more great credit cards
#
#
#
#
#                 By Credit Card Type
#
#
#                 By Credit Card Provider
#
#
#
#
#
# Aeroplan
#
#
# Air Miles
#
#
# Balance Transfer
#
#
# Business
#
#
# Cash Back
#
#
# Gas Reward
#
#
# Guaranteed approval
#
#
# Low Cash Advance
#
#
# Low Interest
#
#
# No Fee
#
#
# No Foreign Transaction Fees
#
#
# Newcomers to Canada
#
#
# Rewards
#
#
# Secured
#
#
# Student
#
#
# Travel
#
#
#
#
# American Express
#
#
# BMO
#
#
# CIBC
#
#
# Home Trust
#
#
# KOHO
#
#
# Mastercard
#
#
# MBNA
#
#
# Neo Financial
#
#
# PC Financial
#
#
# Royal Bank of Canada
#
#
# Scotiabank
#
#
# Tangerine
#
#
# TD
#
#
# Vancity
#
#
# Visa
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Subscribe to our newsletter
#
#                 Stay on top of our latest offers, relevant news and tips!
#
#
#
#
#
#
# Email address
#
#
#
#
#
#
#                                 Yes, I'd like to receive offers and newsletters via email from
#                                 RATESDOTCA. I may unsubscribe at any time.
#
#
#
#
#
#
#
#                                 Sign Up
#
#
#
#
#
#
#
# Thanks for joining!
# You'll be hearing from us shortly - stay tuned.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         Home
#
#
#
#
#
#                         Credit cards
#
#
#
#
# Travel
#
#
#
#
#
#
#
# Our Company
#
#
#
# About Us
# Careers
# Contact Us
# Media
#
#
#
#
# News & Resources
# Affiliates & Partners
# Français
# Corporate
#
#
#
#
#
#
#
#
# Social
#
#
#
#
# Instagram
#
#
#
#
#
# Facebook
#
#
#
#
#
# Twitter
#
#
#
#
#
# YouTube
#
#
#
#
#
# RATESDOTCA
# 225 King St W, Suite 1000, Toronto, ON, M5V 3M2
# 300 Lincoln St. Unit 22Welland, ON L3B 4N4
#
#
#
# 1-844-726-0907
#
#
#
#
#
# support@rates.ca
#
#
#
#
#
#
#
#
#
#                 © 2024 RATESDOTCA  |  a RATESDOTCA Group Ltd. company. All Rights Reserved.
#
#
#
# Terms of Use
# Security
# Accessibility
# Privacy
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# All Links on the Page:
# /
# /insurance-quotes/auto
# /insurance-quotes/auto
# /insurance-quotes/auto/ontario
# /insurance-quotes/auto/alberta
# /insurance-quotes/auto/quebec
# /insurance-quotes/home-auto-insurance-bundle
# /ratesbot
# /insurance-quotes/home
# /insurance-quotes/home
# /insurance-quotes/home/alberta
# /insurance-quotes/condo
# /insurance-quotes/tenant
# /insurance-quotes/home/ontario
# /insurance-quotes/home/british-columbia
# /insurance-quotes/home/contents
# /insurance-quotes/business
# /insurance-quotes/auto/commercial-auto
# /insurance-quotes/commercial-property
# /insurance-quotes/business/general-liability
# /insurance-quotes/business/professional-liability
# /insurance-quotes/business/contractor
# /insurance-quotes/business/pet-care
# /insurance-quotes/business/small-business
# /insurance-quotes/business/personal-services
# /mortgage-rates
# /mortgage-rates
# /mortgage-rates/alberta
# /mortgage-rates/ontario
# /mortgage-rates/british-columbia
# /credit-cards
# /credit-cards
# /credit-cards/rewards
# /credit-cards/low-interest-rates
# /credit-cards/business
# /credit-cards/travel
# /credit-cards/balance-transfer
# /guides/credit-cards
# /credit-cards/cash-back
# /credit-cards/student
# /credit-cards/travel-insurance
# /credit-cards/no-fees
# /credit-cards/no-foreign-transaction-fees
# /credit-cards/secured
# /credit-cards/special-offers
# https://compare.rates.ca/en/credit/login
# /more-products
# /insurance-quotes/travel
# /insurance-quotes/travel/visitors-to-canada
# /insurance-quotes/travel/international-student
# /insurance-quotes/travel/super-visa
# /insurance-quotes/travel/snowbird
# /insurance-quotes/life
# /insurance-quotes/motorcycle-insurance
# /bank-accounts/savings
# /bank-accounts/chequing
# /bank-accounts/seniors
# /bank-accounts/childrens
# /bank-accounts/tfsa
# /gic-rates
# /gic-rates/rrsp
# /resources
# /insuramap/auto
# /guides/car-insurance
# /car-insurance-calculator
# /insurance-quotes/auto/ontario/rate-tracker
# /insurance-quotes/auto/alberta/rate-tracker
# /insuramap/home
# /guides/home-insurance
# /mortgage-calculators
# /guides/mortgage
# /mortgage-report
# /guides/credit-cards
# /resources
#
#
#
#
# https://ratesdotca.travelguardian.ca/fr/formulaire-sortant-ratesdotca/
# https://www.karmainsurance.ca/life-insurance/app/info?utm_source=ratesdotca&postal=V6E4V2
# https://info.apollocover.com/ratesdotca
#
# https://rates.ca/credit-cards/special-offers
# #best-travel
# #points
# #fees
# #best-no-fee-travel
# https://rates.ca/credit-cards/best-of-finance#methodology
# #travel-winner
# #rbc-avion
# #travel-3
# https://compare.rates.ca/en/credit/cards/71/profile
# https://compare.rates.ca/en/credit/cards/71/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/71/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/71/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/71/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/71/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/282/profile
# https://compare.rates.ca/en/credit/cards/343/profile
# https://rates.ca/credit-cards#methodology
# https://click.linksynergy.com/fs-bin/click?id=zYrzX25fHGA&offerid=812227.285&type=3&subid=0
# #top
# #points-winner
# #gold
# #CIBC Aventura® Visa Infinite* Card - Earning
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/433/profile
# https://compare.rates.ca/en/credit/cards/314/profile
# https://rates.ca/resources/ring-american-express-cobalt-credit-card-vs-scotiabank-gold-american-express-card
# https://compare.rates.ca/en/credit/cards/71/profile
# #top
# #transaction-winner
# #transaction-3
# #Home Trust Preferred Visa* Card
# https://compare.rates.ca/en/credit/cards/314/profile?
# https://compare.rates.ca/en/credit/cards/314/profile?preference=perks&rewardPreference=both
# https://www.sceneplus.ca/terms-and-conditions
# https://compare.rates.ca/en/credit/cards/314/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/314/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/314/profile?preference=perks&rewardPreference=both
# https://www.sceneplus.ca/terms-and-conditions
# https://compare.rates.ca/en/credit/cards/314/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/479/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/491/profile
# #top
# #mbna
# #CIBC-Aventura-Visa-Card
# #Scotiabank-American-Express-Card
# https://compare.rates.ca/en/credit/cards/488/profile
# https://compare.rates.ca/en/credit/cards/488/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/488/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/488/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/488/profile?preference=perks&rewardPreference=both
# https://compare.rates.ca/en/credit/cards/488/profile?preference=perks&rewardPreference=both
# https://click.linksynergy.com/fs-bin/click?id=zYrzX25fHGA&offerid=597982.553&type=3&subid=0
# https://compare.rates.ca/en/credit/cards/493/profile
# https://compare.rates.ca/en/credit/cards/337/profile
# #top
# https://rates.ca/credit-cards/balance-transfer
# https://rates.ca/credit-cards/secured
# https://rates.ca/resources/getting-the-most-value-from-your-travel-rewards
# https://rates.ca/credit-cards/travel-insurance
# https://rates.ca/resources/best-premium-perks-credit-card-in-canada-for-2020
# https://rates.ca/credit-cards/air-miles
# https://rates.ca/resources/air-canada-expands-aeroplan-bonuses-and-adds-more-flexibility-members
# https://rates.ca/resources/are-credit-cards-annual-fees-worth-it
# https://rates.ca/guides/credit-cards/interest-rate
# https://rates.ca/credit-cards/no-foreign-transaction-fees
# https://rates.ca/credit-cards#winners
# https://rates.ca/credit-cards/no-fees#top
# https://rates.ca/credit-cards/no-fees#best-no-fee-travel
# https://rates.ca/credit-cards/cash-back#top
# https://rates.ca/credit-cards/low-interest-rates#top
# https://rates.ca/credit-cards/balance-transfer#top
# https://rates.ca/credit-cards/secured#top
# https://rates.ca/credit-cards/rewards#best-young
# https://rates.ca/credit-cards/student#top
# https://rates.ca/credit-cards/travel#fees
# https://rates.ca/credit-cards/rewards#best-family
# https://rates.ca/credit-cards/rewards#best-ordering-in
# https://rates.ca/credit-cards/cash-back#top
# https://rates.ca/resources/this-years-best-credit-cards-for-groceries
# https://rates.ca/resources/this-years-best-credit-cards-for-groceries
# https://rates.ca/resources/top-credit-cards-roadside-assistance-canada
# https://rates.ca/resources/top-credit-cards-roadside-assistance-canada
# https://rates.ca/resources/credit-card-balance-protection-insurance-worthwhile
# https://rates.ca/resources/credit-card-balance-protection-insurance-worthwhile
# /credit-cards/aeroplan-credit-cards
# /credit-cards/air-miles
# /credit-cards/balance-transfer
# /credit-cards/business
# /credit-cards/cash-back
# /credit-cards/gas-rewards
# /credit-cards/guaranteed-approval
# /credit-cards/low-cash-advance
# /credit-cards/low-interest-rates
# /credit-cards/no-fees
# /credit-cards/no-foreign-transaction-fees
# /credit-cards/newcomers-credit-cards
# /credit-cards/rewards
# /credit-cards/secured
# /credit-cards/student
# /credit-cards/travel
# /credit-cards/american-express
# /credit-cards/bmo
# /credit-cards/cibc
# /credit-cards/home-trust
# /credit-cards/koho
# /credit-cards/mastercard
# /credit-cards/mbna
# /credit-cards/neo-financial
# /credit-cards/pc-financial
# /credit-cards/rbc
# /credit-cards/scotiabank
# /credit-cards/tangerine
# /credit-cards/td-canada-trust
# /credit-cards/vancity
# /credit-cards/visa
# /
# /credit-cards
# /about-us
# //corporate.rates.ca/#careers-snippet-careers
# /contact-us
# /media
# /resources
# /sign-up
# /fr
# //corporate.rates.ca
# https://www.instagram.com/RATESDOTCA
# https://www.facebook.com/RATESDOTCA
# https://twitter.com/RATESDOTCA
# https://www.youtube.com/c/RATESDOTCA
# tel:1-844-726-0907
# mailto:support@rates.ca
# //corporate.rates.ca
# /terms-of-use
# /security
# /accessibility
# /privacy-policy

# %%
print(len(soup.get_text()))
# Out:
# 66713

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Set options for headless browsing (optional)
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")

# Automatically manage ChromeDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Load the webpage
url = r"https://rates.ca/credit-cards/travel"
driver.get(url)

# Extract and measure the length of the HTML
html = driver.page_source
html_length = len(html)

# Print the length of the HTML content
print(f"Length of HTML content: {html_length} characters")



driver.quit()
# Out:
# Length of HTML content: 1128745 characters

# %%
open('file.txt', 'w').close()

with open('/Users/aaryas127/Documents/GitHub/credit_card_reward_maximizer/data_storage/html.txt', 'w') as f:
    f.write(html)

# %%
# import faiss
# import numpy as np
# from sentence_transformers import SentenceTransformer
# from transformers import GPT2LMHeadModel, GPT2Tokenizer

# # Read the file content
# with open("html.txt", "r") as file:
#     file_content = file.read()

# # Split the content into chunks (e.g., sentences or paragraphs)
# file_chunks = file_content.split("\n")

# # Initialize the embedding model (using sentence-transformers)
# embedder = SentenceTransformer('all-MiniLM-L6-v2')

# # Embed each chunk of the file
# embeddings = embedder.encode(file_chunks)

# # Initialize FAISS index for similarity search
# index = faiss.IndexFlatL2(embeddings.shape[1])  # L2 distance metric
# index.add(np.array(embeddings))  # Add the embeddings to the index

# # Example query
# query = "What is the main topic of the text?"

# # Embed the query
# query_embedding = embedder.encode([query])

# # Retrieve the most similar chunk using FAISS
# D, I = index.search(np.array(query_embedding), k=1)  # k=1 for top-1 closest match

# # Get the closest chunk from the file
# closest_chunk = file_chunks[I[0][0]]

# # Initialize a generative model (GPT-2 example)
# tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# model = GPT2LMHeadModel.from_pretrained("gpt2")

# # Prepare the input for the model
# input_text = f"Question: {query}\nAnswer: {closest_chunk}"
# inputs = tokenizer(input_text, return_tensors="pt")

# # Generate an answer using the model
# output = model.generate(inputs['input_ids'], max_length=50)
# generated_answer = tokenizer.decode(output[0], skip_special_tokens=True)

# print(generated_answer)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 import faiss
#       2 import numpy as np
# ----> 3 from sentence_transformers import SentenceTransformer
#       4 from transformers import GPT2LMHeadModel, GPT2Tokenizer
#       6 # Read the file content
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sentence_transformers/__init__.py:14
#       7 import os
#       9 from sentence_transformers.backend import (
#      10     export_dynamic_quantized_onnx_model,
#      11     export_optimized_onnx_model,
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#      15 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      16 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sentence_transformers/cross_encoder/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       5 __all__ = ["CrossEncoder"]
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:18
#      15 from transformers.tokenization_utils_base import BatchEncoding
#      16 from transformers.utils import PushToHubMixin
# ---> 18 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      19 from sentence_transformers.readers import InputExample
#      20 from sentence_transformers.SentenceTransformer import SentenceTransformer
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sentence_transformers/evaluation/__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .BinaryClassificationEvaluator import BinaryClassificationEvaluator
#       4 from .EmbeddingSimilarityEvaluator import EmbeddingSimilarityEvaluator
#       5 from .InformationRetrievalEvaluator import InformationRetrievalEvaluator
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sentence_transformers/evaluation/BinaryClassificationEvaluator.py:10
#       7 from typing import TYPE_CHECKING, Literal
#       9 import numpy as np
# ---> 10 from sklearn.metrics import average_precision_score
#      11 from sklearn.metrics.pairwise import paired_cosine_distances, paired_euclidean_distances, paired_manhattan_distances
#      13 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/__init__.py:84
#      70     # We are not importing the rest of scikit-learn during the build
#      71     # process, as it may not be compiled yet
#      72 else:
#    (...)
#      78     # later is linked to the OpenMP runtime to make it possible to introspect
#      79     # it and importing it first would fail if the OpenMP dll cannot be found.
#      80     from . import (
#      81         __check_build,  # noqa: F401
#      82         _distributor_init,  # noqa: F401
#      83     )
# ---> 84     from .base import clone
#      85     from .utils._show_versions import show_versions
#      87     __all__ = [
#      88         "calibration",
#      89         "cluster",
#    (...)
#     130         "show_versions",
#     131     ]
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/base.py:19
#      17 from ._config import config_context, get_config
#      18 from .exceptions import InconsistentVersionWarning
# ---> 19 from .utils._estimator_html_repr import _HTMLDocumentationLinkMixin, estimator_html_repr
#      20 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
#      21 from .utils._param_validation import validate_parameter_constraints
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/__init__.py:11
#       9 from . import _joblib, metadata_routing
#      10 from ._bunch import Bunch
# ---> 11 from ._chunking import gen_batches, gen_even_slices
#      12 from ._estimator_html_repr import estimator_html_repr
#      14 # Make _safe_indexing importable from here for backward compat as this particular
#      15 # helper is considered semi-private and typically very useful for third-party
#      16 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      17 # _safe_indexing was included in our public API documentation despite the leading
#      18 # `_` in its name.
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/_chunking.py:8
#       5 import numpy as np
#       7 from .._config import get_config
# ----> 8 from ._param_validation import Interval, validate_params
#      11 def chunk_generator(gen, chunksize):
#      12     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      13     chunk may have a length less than ``chunksize``."""
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:14
#      11 from scipy.sparse import csr_matrix, issparse
#      13 from .._config import config_context, get_config
# ---> 14 from .validation import _is_arraylike_not_scalar
#      17 class InvalidParameterError(ValueError, TypeError):
#      18     """Custom exception to be raised when the parameter of a class/method/function
#      19     does not have a valid type or value.
#      20     """
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/validation.py:26
#      24 from .. import get_config as _get_config
#      25 from ..exceptions import DataConversionWarning, NotFittedError, PositiveSpectrumWarning
# ---> 26 from ..utils._array_api import _asarray_with_order, _is_numpy_namespace, get_namespace
#      27 from ..utils.fixes import ComplexWarning, _preserve_dia_indices_dtype
#      28 from ._isfinite import FiniteStatus, cy_isfinite
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/_array_api.py:11
#       8 import scipy.special as special
#      10 from .._config import get_config
# ---> 11 from .fixes import parse_version
#      13 _NUMPY_NAMESPACE_NAMES = {"numpy", "array_api_compat.numpy"}
#      16 def yield_namespaces(include_numpy_namespaces=True):
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/sklearn/utils/fixes.py:21
#      19 import scipy
#      20 import scipy.sparse.linalg
# ---> 21 import scipy.stats
#      23 try:
#      24     import pandas as pd
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/stats/__init__.py:610
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     605
#     606 """  # noqa: E501
#     608 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     609                                DegenerateDataWarning, FitError)
# --> 610 from ._stats_py import *
#     611 from ._variation import variation
#     612 from .distributions import *
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/stats/_stats_py.py:49
#      46 # Import unused here but needs to stay until end of deprecation periode
#      47 # See https://github.com/scipy/scipy/issues/15765#issuecomment-1875564522
#      48 from scipy import linalg  # noqa: F401
# ---> 49 from . import distributions
#      50 from . import _mstats_basic as mstats_basic
#      52 from ._stats_mstats_common import _find_repeats, theilslopes, siegelslopes
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/stats/distributions.py:10
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
#       8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)  # noqa: F401
# ---> 10 from . import _continuous_distns
#      11 from . import _discrete_distns
#      13 from ._continuous_distns import *  # noqa: F403
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/stats/_continuous_distns.py:12
#      10 import numpy as np
#      11 from numpy.polynomial import Polynomial
# ---> 12 from scipy.interpolate import BSpline
#      13 from scipy._lib.doccer import (extend_notes_in_docstring,
#      14                                replace_notes_in_docstring,
#      15                                inherit_docstring_from)
#      16 from scipy._lib._ccallback import LowLevelCallable
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/interpolate/__init__.py:167
#       1 """
#       2 ========================================
#       3 Interpolation (:mod:`scipy.interpolate`)
#    (...)
#     165 (should not be used in new code).
#     166 """
# --> 167 from ._interpolate import *
#     168 from ._fitpack_py import *
#     170 # New interface to fitpack library:
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/interpolate/_interpolate.py:12
#       9 from scipy._lib._util import copy_if_needed
#      10 from scipy.special import comb
# ---> 12 from . import _fitpack_py
#      13 from ._polyint import _Interpolator1D
#      14 from . import _ppoly
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/interpolate/_fitpack_py.py:8
#       5 import numpy as np
#       7 # These are in the API for fitpack even if not used in fitpack.py itself.
# ----> 8 from ._fitpack_impl import bisplrep, bisplev, dblint  # noqa: F401
#       9 from . import _fitpack_impl as _impl
#      10 from ._bsplines import BSpline
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/scipy/interpolate/_fitpack_impl.py:103
#      52 _iermess = {
#      53     0: ["The spline has a residual sum of squares fp such that "
#      54         "abs(fp-s)/s<=0.001", None],
#    (...)
#      68     'unknown': ["An error occurred", TypeError]
#      69 }
#      71 _iermess2 = {
#      72     0: ["The spline has a residual sum of squares fp such that "
#      73         "abs(fp-s)/s<=0.001", None],
#    (...)
#      99     'unknown': ["An error occurred", TypeError]
#     100 }
#     102 _parcur_cache = {'t': array([], float), 'wrk': array([], float),
# --> 103                  'iwrk': array([], dfitpack_int), 'u': array([], float),
#     104                  'ub': 0, 'ue': 1}
#     107 def splprep(x, w=None, u=None, ub=None, ue=None, k=3, task=0, s=None, t=None,
#     108             full_output=0, nest=None, per=0, quiet=1):
#     109     # see the docstring of `_fitpack_py/splprep`
#     110     if task <= 0:
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:149, in _scalar_str(dtype, short)
#     146 elif dtype.type == np.timedelta64:
#     147     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 149 elif np.issubdtype(dtype, np.number):
#     150     # Short repr with endianness, like '<f8'
#     151     if short or dtype.byteorder not in ('=', '|'):
#     152         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/core/numerictypes.py:416, in issubdtype(arg1, arg2)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:149, in _scalar_str(dtype, short)
#     146 elif dtype.type == np.timedelta64:
#     147     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 149 elif np.issubdtype(dtype, np.number):
#     150     # Short repr with endianness, like '<f8'
#     151     if short or dtype.byteorder not in ('=', '|'):
#     152         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/core/numerictypes.py:416, in issubdtype(arg1, arg2)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
#     [... skipping similar frames: __repr__ at line 46 (464 times), _construction_repr at line 100 (464 times), _scalar_str at line 149 (463 times), issubdtype at line 416 (463 times)]
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:149, in _scalar_str(dtype, short)
#     146 elif dtype.type == np.timedelta64:
#     147     return "'%sm8%s'" % (byteorder, _datetime_metadata_str(dtype))
# --> 149 elif np.issubdtype(dtype, np.number):
#     150     # Short repr with endianness, like '<f8'
#     151     if short or dtype.byteorder not in ('=', '|'):
#     152         return "'%s%c%d'" % (byteorder, dtype.kind, dtype.itemsize)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/core/numerictypes.py:416, in issubdtype(arg1, arg2)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:46, in __repr__(dtype)
#      45 def __repr__(dtype):
# ---> 46     arg_str = _construction_repr(dtype, include_align=False)
#      47     if dtype.isalignedstruct:
#      48         arg_str = arg_str + ", align=True"
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:100, in _construction_repr(dtype, include_align, short)
#      98     return _subarray_str(dtype)
#      99 else:
# --> 100     return _scalar_str(dtype, short=short)
#
# File ~/Documents/GitHub/pharmapp/.conda/lib/python3.11/site-packages/numpy/_core/_dtype.py:104, in _scalar_str(dtype, short)
#     103 def _scalar_str(dtype, short):
# --> 104     byteorder = _byte_order_str(dtype)
#     106     if dtype.type == np.bool:
#     107         if short:
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# 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

# %%
# Reading the entire file content
with open("/Users/aaryas127/Documents/GitHub/credit_card_reward_maximizer/api.txt", 'r') as file:
    content = file.read()

from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = str(content)
)

completion = client.chat.completions.create(
  model="nvidia/llama-3.1-nemotron-70b-instruct",
  messages=[{"role":"user","content":soup.get_text()}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")
# Out:
# Here's a summary of the article "Canada's Best Travel Credit Cards of 2024":
#
# **Top Travel Credit Cards in Canada for 2024:**
#
# 1. **Best Overall Travel Credit Card:**
# 	* **CIBC Aventura Visa Infinite Card**
# 	* First-year value: $1,536
# 	* Credit score required: Excellent (≥720)
# 	* Top features: NEXUS Application Fee Rebate, complimentary lounge visits, and travel insurance
# 2. **Best Credit Card for Earning Travel Points:**
# 	* **American Express Cobalt Credit Card**
# 	* First-year value: $1,361
# 	* Credit score required: Fair (<660)
# 	* Top features: Flexible rewards points, travel insurance, and no foreign transaction fees
# 3. **Best Credit Card with No Foreign Transaction Fees:**
# 	* **Scotiabank Gold American Express Card**
# 	* First-year value: $1,194
# 	* Credit score required: Good (660+)
# 	* Top features: No foreign transaction fees, flexible Scotia rewards program, and travel insurance
# 4. **Best No-Fee Travel Credit Card:**
# 	* **MBNA Rewards Platinum Plus Mastercard**
# 	* First-year value: $645
# 	* Credit score required: Good (660+)
# 	* Top features: Earn 4 points for every $1 spent on eligible purchases, travel insurance, and no annual fee
#
# **Other Notable Mentions:**
#
# * RBC Avion Visa Infinite
# * TD Aeroplan Visa Infinite Card
# * Scotiabank Passport Visa Infinite Card
# * Home Trust Preferred Visa Card
# * CIBC Aventura Visa Card
# * Scotiabank American Express Card
#
# **Things to Consider Before Choosing a Travel Credit Card:**
#
# * Eligibility: Typically requires a credit score of 650 or higher
# * Annual Fees: Range from $100-$150, but some cards waive the first-year fee
# * Pros:
# 	+ Higher earn rates
# 	+ Welcome bonus offers
# 	+ Travel rewards and insurance
# 	+ Perks like lounge access and hotel upgrades
# * Cons:
# 	+ Fluctuating rewards programs
# 	+ Blackout dates
# 	+ High annual fees
# 	+ High interest charges if not paid in full
# 	+ Foreign transaction fees (some cards)

# %%
# Cashback

# %%
# Travel Benefits

completion = client.chat.completions.create(
  model="meta/llama-3.1-405b-instruct",
  messages=[{"role":"user","content":"Does the Desjardins Flexi Visa have any travel benefits?"}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")

# %%
# Signup Bonus, Points, Spending requirement

completion = client.chat.completions.create(
  model="meta/llama-3.1-405b-instruct",
  messages=[{"role":"user","content":"Does the Desjardins Flexi Visa have the ability to get you any sort of points?"}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=True
)

for chunk in completion:
  if chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")

# %%
# Insurance

# %%
# Annual fee...first year free?
